# %% [markdown]
# # Getting Started with Jupyter Notebooks

# %% [markdown]
# ## 1. Importing Libraries

# %%
import pandas as pd

# %% [markdown]
# ## 2. Load the Dataset

# %%
df = pd.read_csv("data/NY-House-Dataset.csv")

# %%
df[df.columns[:5]]
# Out:
#                                             BROKERTITLE                TYPE  \
# 0           Brokered by Douglas Elliman  -111 Fifth Ave      Condo for sale
# 1                                   Brokered by Serhant      Condo for sale
# 2                                Brokered by Sowae Corp      House for sale
# 3                                   Brokered by COMPASS      Condo for sale
# 4     Brokered by Sotheby's International Realty - E...  Townhouse for sale
# ...                                                 ...                 ...
# 4796                                Brokered by COMPASS      Co-op for sale
# 4797                    Brokered by Mjr Real Estate Llc      Co-op for sale
# 4798      Brokered by Douglas Elliman - 575 Madison Ave      Co-op for sale
# 4799            Brokered by E Realty International Corp      Condo for sale
# 4800                 Brokered by Nyc Realty Brokers Llc      Co-op for sale
#
#           PRICE  BEDS       BATH
# ...

# %%
df[df.columns[-5:]]
# Out:
#            STREET_NAME         LONG_NAME  \
# 0     East 55th Street   Regis Residence
# 1             New York  West 57th Street
# 2        Staten Island   Sinclair Avenue
# 3             New York  East 55th Street
# 4             New York  East 64th Street
# ...                ...               ...
# 4796         Manhattan               222
# 4797            Queens        62nd Drive
# 4798          New York  West 21st Street
# 4799          Flushing             91-23
# 4800      Coney Island               460
#
#                                       FORMATTED_ADDRESS   LATITUDE  LONGITUDE
# 0     Regis Residence, 2 E 55th St #803, New York, N...  40.761255 -73.974483
# 1                217 W 57th St, New York, NY 10019, USA  40.766393 -73.980991
# 2        620 Sinclair Ave, Staten Island, NY 10312, USA  40.541805 -74.196109
# 3                  2 E 55th St, New York, NY 10022, USA  40.761398 -73.974613
# ...

# %%
df.select_dtypes("int")
# Out:
#           PRICE  BEDS
# 0        315000     2
# 1     195000000     7
# 2        260000     4
# 3         69000     3
# 4      55000000     7
# ...         ...   ...
# 4796     599000     1
# 4797     245000     1
# 4798    1275000     1
# 4799     598125     2
# 4800     349000     1
#
# [4801 rows x 2 columns]

# %% [markdown]
# ## 5. loc and iloc

# %%
df.iloc[:, 1:3]
# Out:
#                     TYPE      PRICE
# 0         Condo for sale     315000
# 1         Condo for sale  195000000
# 2         House for sale     260000
# 3         Condo for sale      69000
# 4     Townhouse for sale   55000000
# ...                  ...        ...
# 4796      Co-op for sale     599000
# 4797      Co-op for sale     245000
# 4798      Co-op for sale    1275000
# 4799      Condo for sale     598125
# 4800      Co-op for sale     349000
#
# [4801 rows x 2 columns]

# %%
# df.loc[(df['BEDS'] > 5) & (df['BATH'] == 2)]

# %% [markdown]
# ## 6. Querying Data

# %%
# df.query("(BEDS > 5) and (BATH == 2)")

# %% [markdown]
# ## Homework #1

# %%
df.iloc[5:10,3:5]
# Out:
#    BEDS  BATH
# 5     5   2.0
# 6     2   2.0
# 7     8  16.0
# 8     1   1.0
# 9     2   1.0

# %%
df.iloc[-1,:]
# Out:
# BROKERTITLE                               Brokered by Nyc Realty Brokers Llc
# TYPE                                                          Co-op for sale
# PRICE                                                                 349000
# BEDS                                                                       1
# BATH                                                                     1.0
# PROPERTYSQFT                                                           750.0
# ADDRESS                                              460 Neptune Ave Apt 14O
# STATE                                                     Brooklyn, NY 11224
# MAIN_ADDRESS                       460 Neptune Ave Apt 14OBrooklyn, NY 11224
# ADMINISTRATIVE_AREA_LEVEL_2                                         New York
# LOCALITY                                                        Kings County
# SUBLOCALITY                                                         Brooklyn
# ...

# %%
df.iloc[[-1]]
# Out:
#                              BROKERTITLE            TYPE   PRICE  BEDS  BATH  \
# 4800  Brokered by Nyc Realty Brokers Llc  Co-op for sale  349000     1   1.0
#
#       PROPERTYSQFT                  ADDRESS               STATE  \
# 4800         750.0  460 Neptune Ave Apt 14O  Brooklyn, NY 11224
#
#                                    MAIN_ADDRESS ADMINISTRATIVE_AREA_LEVEL_2  \
# 4800  460 Neptune Ave Apt 14OBrooklyn, NY 11224                    New York
#
#           LOCALITY SUBLOCALITY   STREET_NAME LONG_NAME  \
# 4800  Kings County    Brooklyn  Coney Island       460
#
#                                   FORMATTED_ADDRESS   LATITUDE  LONGITUDE
# 4800  460 Neptune Ave #14a, Brooklyn, NY 11224, USA  40.579147 -73.970949

# %%
df.loc[15:20, ['TYPE', 'BATH']]
# Out:
#                   TYPE  BATH
# 15      Condo for sale   2.0
# 16  Townhouse for sale   2.0
# 17      Co-op for sale   1.0
# 18      Co-op for sale   1.0
# 19      Condo for sale   2.0
# 20      House for sale   2.0

# %%
df.loc[(df['PROPERTYSQFT']>5000)].loc[:, ['PROPERTYSQFT', 'MAIN_ADDRESS']]
# Out:
#       PROPERTYSQFT                                       MAIN_ADDRESS
# 1          17545.0  Central Park Tower Penthouse-217 W 57th New Yo...
# 4          14175.0                      5 E 64th StNew York, NY 10065
# 7          33000.0             177 Benedict RdStaten Island, NY 10304
# 27          5670.0                     2361 81st StBrooklyn, NY 11214
# 32          5040.0        366 Union Ave Unit 4Staten Island, NY 10303
# ...            ...                                                ...
# 4651        7327.0                141-143 E 63rd StNew York, NY 10065
# 4691       12733.0                    2245 Creston AveBronx, NY 10453
# 4722        5427.0                838 5th Ave Fl 6Manhattan, NY 10065
# 4745        7040.0  115-117 W 87th St Unit TownhouseManhattan, NY ...
# 4792        7854.0                      448 40th StBrooklyn, NY 11232
#
# [203 rows x 2 columns]

# %%
df.loc[(df['PROPERTYSQFT']>5000) & (df['BEDS']>5)].loc[:, ['PROPERTYSQFT', 'MAIN_ADDRESS', 'BEDS']]
# Out:
#       PROPERTYSQFT                                       MAIN_ADDRESS  BEDS
# 1          17545.0  Central Park Tower Penthouse-217 W 57th New Yo...     7
# 4          14175.0                      5 E 64th StNew York, NY 10065     7
# 7          33000.0             177 Benedict RdStaten Island, NY 10304     8
# 27          5670.0                     2361 81st StBrooklyn, NY 11214    12
# 32          5040.0        366 Union Ave Unit 4Staten Island, NY 10303    10
# ...            ...                                                ...   ...
# 4532        6800.0                    180 E 73rd StNew York, NY 10021     6
# 4595        6000.0               175-177 E 78th StManhattan, NY 10075     8
# 4651        7327.0                141-143 E 63rd StNew York, NY 10065     8
# 4691       12733.0                    2245 Creston AveBronx, NY 10453     6
# 4745        7040.0  115-117 W 87th St Unit TownhouseManhattan, NY ...     7
#
# [135 rows x 3 columns]

# %%
df.query("TYPE == 'Condo for sale'")
# Out:
#                                         BROKERTITLE            TYPE  \
# 0       Brokered by Douglas Elliman  -111 Fifth Ave  Condo for sale
# 1                               Brokered by Serhant  Condo for sale
# 3                               Brokered by COMPASS  Condo for sale
# 6     Brokered by Douglas Elliman - 575 Madison Ave  Condo for sale
# 15                         Brokered by Awaye Realty  Condo for sale
# ...                                             ...             ...
# 4784                  Brokered by Akcess24homes Inc  Condo for sale
# 4787    Brokered by REAL NEW YORK - Remote Brooklyn  Condo for sale
# 4790                            Brokered by Serhant  Condo for sale
# 4794               Brokered by Brown Harris Stevens  Condo for sale
# 4799        Brokered by E Realty International Corp  Condo for sale
#
#           PRICE  BEDS       BATH  PROPERTYSQFT  \
# 0        315000     2   2.000000   1400.000000
# 1     195000000     7  10.000000  17545.000000
# ...

# %%
df.query("PRICE < 400000 and SUBLOCALITY=='The Bronx'")
# Out:
#                                             BROKERTITLE            TYPE  \
# 10                 Brokered by Engel & Volkers Americas  Co-op for sale
# 18                   Brokered by Coldwell Banker Realty  Co-op for sale
# 43                     Brokered by Brown Harris Stevens  Co-op for sale
# 146                  Brokered by RE MAX Boutique Realty  Co-op for sale
# 205   Brokered by Sotheby's International Realty - D...  Co-op for sale
# ...                                                 ...             ...
# 4591             Brokered by Corcoran Westside Columbus  Co-op for sale
# 4662                                Brokered by COMPASS  Co-op for sale
# 4692                        Brokered by Mp Power Realty  Co-op for sale
# 4731                   Brokered by Brown Harris Stevens  Co-op for sale
# 4732  Brokered by OneKey MLS LLC - Foxworth Realty, ...  Co-op for sale
#
#        PRICE  BEDS  BATH  PROPERTYSQFT                          ADDRESS  \
# ...
